# %% [markdown]
# ## Delaunay Plot

# %%
from scipy.spatial import Delaunay, delaunay_plot_2d, Voronoi, voronoi_plot_2d
import matplotlib.pyplot as plt
import numpy as np

w = h = 360

n = 1000
np.random.seed(0)
pts = np.random.randint(0, w, (n, 2))

print(pts)
print(type(pts))
print(pts.shape)
# Out:
# [[172  47]
#  [117 192]
#  [323 251]
#  ...
#  [277 119]
#  [283 309]
#  [293   7]]
# <class 'numpy.ndarray'>
# (1000, 2)

# %%
tri = Delaunay(pts)

print(type(tri))

fig = delaunay_plot_2d(tri)
fig.savefig('/mnt/scipy_matplotlib_delaunay.png')
# Out:
# <class 'scipy.spatial._qhull.Delaunay'>
