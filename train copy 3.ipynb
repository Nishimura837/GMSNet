# %% [markdown]
# ## 完成したtrain copy.ipynb　を使って、ある条件を基に格子を集めていくものを作りたい
# 2024/5/17 時点での完成版
#
# コードをすべて問題なく実行できるようにはなった。
# 最適化されたメッシュを取り出してくることもでき、しっかり更新できている。
# しかし、損失の値が全く減少せず、むしろ増加していてほぼもともとのメッシュのままの出力が最適化メッシュとして出てきてしまう。
# ゆえに、最適化できているとは到底言えない。

# %% [markdown]
# trainを実行するためのコード

# %% [markdown]
# ・各epoch後のメッシュの表示

# %% [markdown]
# ・学習率を0.1倍から0.95倍にしてみる

# %% [markdown]
# ・シフト切り捨ては推論時飲み使用する

# %% [markdown]
# ・バッチサイズを変えてみる

# %% [markdown]
# ・モデルの出力を0.5倍するなどして移動量を小さくする

# %% [markdown]
# ・学習時はMetricLossで、最適メッシュを選定するときは違う関数なのはなんで

# %% [markdown]
# # シフト切り捨てをやめてみる
# # トレーニング完了後のトレーニングメッシュを表示してみる
# # 各epochの終了時にメッシュを可視化してみる

# %%
import copy
import numpy as np
import torch
from torch.utils.data import Dataset
from torch.utils.tensorboard import SummaryWriter
from torch_geometric.nn import GCNConv
from torch_geometric.nn import GraphNorm, LayerNorm
import torch.nn.functional as F
import torch_geometric.transforms as T
from torch.nn import Linear, InstanceNorm2d, InstanceNorm1d, Conv1d, ReLU, Tanh
from torch.optim.lr_scheduler import ReduceLROnPlateau
import random
import matplotlib.pyplot as plt
from torch_geometric.transforms import FaceToEdge
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from itertools import combinations
import vtk
import glob
from tqdm import tqdm
# 計算を軽くするためのライブラリ
from torch.cuda import empty_cache
import gc               # メモリリークを防ぐ

from torch import nn
import os
import sys

import datetime

# %%
torch.cuda.is_available()
# Out:
# True

# %%
num_train_epoch = 50
train_data_path = "/mnt/new_train_data/"
save_fig_path = "/mnt/Saved_mesh_GNN_trying/"

# %% [markdown]
# # Dataの準備

# %%
class Dataset(Dataset):
    def __init__(self, num_files):
        None

class Mesh(Dataset):
    def __init__(self):
        self.coordinates = None
        self.faces = None

class Polygon(Dataset):
    def __init__(self, num_node, num_face):
        self.parent_meshID = None
        self.coordinates = torch.zeros(num_node, 2)
        self.faces = torch.zeros(num_face, 3)
        self.edge_index = None
        self.edges = None
        self.d = None
        self.Cx = None
        self.Cy = None
        self.x_min = None
        self.y_min = None

    def to(self, device):
        # GPUに移動可能なtorch.Tensor変数を移動
        self.coordinates = self.coordinates.to(device)
        self.faces = self.faces.to(device)
        if self.edge_index is not None:
            self.edge_index = self.edge_index.to(device)
        if self.edges is not None:
            self.edges = self.edges.to(device)
        if self.d is not None:
            self.d = self.d.to(device)
        if self.Cx is not None:
            self.Cx = self.Cx.to(device)
        if self.Cy is not None:
            self.Cy = self.Cy.to(device)
        if self.x_min is not None:
            self.x_min = self.x_min.to(device)
        if self.y_min is not None:
            self.y_min = self.y_min.to(device)

class PolygonID(Dataset):
    def __init__(self, nodeID):
        self.nodeID = nodeID
        # self.parent_meshID = None

class Polygon_data(Dataset):
    def __init__(self, polygonID, meshID, nodeID):
        self.polygonID = polygonID
        self.meshID = meshID
        self.nodeID = nodeID

class Minibatch(Dataset):
    def __init__(self):
        self.x = None
        self.edge_index = None
        self.batch = None

class EarlyStopping:
    def __init__(self, patience, min_delta):
        self.patience = patience      # 損失が改善しないエポック数の上限
        self.min_delta = min_delta    # 損失が改善とみなす最小値
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None:
            self.best_loss = val_loss
        elif val_loss > self.best_loss - self.min_delta:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_loss = val_loss
            self.counter = 0

# %%
def create_mesh_polygonID_data(vtk_file_path, polygonID_list, poly_count, polygon_dict, mesh_index):
    reader = vtk.vtkDataSetReader()
    reader.SetFileName(vtk_file_path)
    reader.Update()

    data = reader.GetOutput()
    
    mesh = Mesh()
    # 座標情報を取得
    points = data.GetPoints()
    num_points = points.GetNumberOfPoints()
    coordinates = torch.zeros(num_points, 3)
    for i in range(num_points):
        coordinates[i] = torch.tensor(points.GetPoint(i))

    mesh.coordinates = coordinates[:, :2]                        # mesh.coordinates を定義

    # 面情報を取得
    polys = data.GetPolys()                                     #すべての面情報を取得
    num_polys = polys.GetNumberOfCells()                        #面の数を取得
    mesh.faces = torch.zeros(num_polys, 3, dtype=int)           # 面情報を格納するための行列を定義

    # 各三角形の情報を取得
    polys.InitTraversal()                                       #イテレーションを初期化
    for i in range(num_polys):                          
        cell = vtk.vtkIdList()                                  #vtk.vtkIdList()オブジェクトを作成
        print(cell)                                     
        if polys.GetNextCell(cell) == 0:                        #次のセル（ポリゴン）を取得し、cellにその情報を格納
            break
        mesh.faces[i] = torch.tensor([cell.GetId(0), cell.GetId(1), cell.GetId(2)]) #セル（ポリゴン）の頂点IDを格納
        
# ------------ mesh のデータを取得完了 -------------------------


    # 各セルの各辺の隣接セル数を調べる
    edge_neighbors = {}
    num_cells = data.GetNumberOfCells()
    for cell_index in range(num_cells):
        cell = data.GetCell(cell_index)
        num_edges = cell.GetNumberOfEdges()

        for edge_index in range(num_edges):
            edge = cell.GetEdge(edge_index)
            edge_points = edge.GetPointIds()

            # 辺を構成する点のインデックスを取得
            point1_id = edge_points.GetId(0)
            point2_id = edge_points.GetId(1)

            # 辺を構成する点のインデックスを昇順にソート
            edge_key = (min(point1_id, point2_id), max(point1_id, point2_id))

            # 辺の隣接セル数をカウント
            if edge_key in edge_neighbors:
                edge_neighbors[edge_key] = edge_neighbors[edge_key] +1
            else:
                edge_neighbors[edge_key] = 1 

    boundary_edges = []
    # 境界上の辺を特定
    for edge_key, num_neighbors in edge_neighbors.items():
        if num_neighbors == 1:
            boundary_edges.append(edge_key)

    # 境界上の辺を構成する頂点の番号を取得
    boundary_points = set()     # 集合を表すデータ型、順番を持たず、重複した要素は取り除かれる
# ---------------- 自由点かどうかの判定完了 ------------------------
    

    for edge_key in boundary_edges:
        boundary_points.add(edge_key[0])
        boundary_points.add(edge_key[1])
    
    
    for pointId in range(num_points):       # pointId:自由点の頂点番号
        if pointId in boundary_points:
            continue
        else:
            poly_count = poly_count + 1
            # print("pointId:", pointId)
        mask = (mesh.faces == pointId)
        if mask.any():
            count = torch.sum(mask).item()  
        num_node = count + 1
        num_face = count
        polygon_number = poly_count - 1 



        
        polygon_i = f"polygon_{polygon_number}"
        # print(polygon_i)
        polygon_i = Polygon(num_node, num_face)
        
        element_to_check = pointId
        polygon_i.face = mesh.faces[(mesh.faces == element_to_check).any(dim=1)]
        # print(polygon_i.face)

        polygon_i.nodeId = set()
        for i in range(len(polygon_i.face)):
            polygon_i.nodeId.add(polygon_i.face[i, 0].item())
            polygon_i.nodeId.add(polygon_i.face[i, 1].item())
            polygon_i.nodeId.add(polygon_i.face[i, 2].item())
        sorted_nodeId = sorted(polygon_i.nodeId)
        polygon_i.nodeID = torch.tensor(list(sorted_nodeId))
        
        point_id_index = (polygon_i.nodeID == pointId).nonzero().item()

        value_to_move = polygon_i.nodeID[point_id_index]
        polygon_i.nodeID = torch.cat((value_to_move.unsqueeze(0), polygon_i.nodeID[polygon_i.nodeID != pointId]))
        # print(polygon_i.nodeID)
        setattr(polygon_i, "parent_meshID", mesh)
        polygonID_list.append(f"polygon_{polygon_number}")

        keyword = f"polygon_{polygon_number}"
        valiables = (f"mesh_{mesh_index}", polygon_i.nodeID)
        polygon_dict[keyword] = valiables

    # --------- polygon.nodeID の取得完了 -------------
    return mesh, polygonID_list, poly_count, polygon_dict

# %% [markdown]
# # Dataset の作成

# %%
def create_mesh_polygon_dataset(vtk_files):
    num_vtk_files = len(vtk_files)
    polygonID_list = []
    mesh_data_list = []
    poly_count = 0
    polygon_dict = {}
    # ファイルに順にアクセスする
    for i in range(num_vtk_files):
        # print("File Name:", vtk_files[i])
        mesh, polygonID_list, poly_count, polygon_dict = create_mesh_polygonID_data(vtk_files[i], polygonID_list, poly_count, polygon_dict, i)
        mesh_data_list.append(mesh)
    return mesh_data_list, polygonID_list, polygon_dict

# %%
# 以下、i はpolygon番号で座標と面情報を取得することができる
face_to_edge = T.FaceToEdge(remove_faces=False)
def data_getter(polygonID, num_mesh_data_list, mesh_data_list, polygon_data_list):
    
    polygon_meshID = int(polygon_data_list[polygonID].meshID.split("_")[-1])
    mesh = mesh_data_list[polygon_meshID]
    
    num_node = len(polygon_data_list[polygonID].nodeID)
    num_face = num_node - 1 
    polygon_i = Polygon(num_node, num_face)

    # print(polygon_data_list[polygonID].nodeID)      # polygon に属する頂点の番号

    polygon_i.coordinates = mesh.coordinates[polygon_data_list[polygonID].nodeID]     # polygonの座標
    # print(polygon_i.coordinates)

    # print(polygon_i.faces)

    # polygon_i.faces を取得するコード
    
    element_to_check = polygon_data_list[polygonID].nodeID[0]
    polygon_i.face = mesh.faces[(mesh.faces == element_to_check).any(dim=1)]

    indices = torch.nonzero(torch.isin(polygon_i.face, polygon_data_list[polygonID].nodeID))
    for idx in range(indices.size(0)):
        row_idx, col_idx = indices[idx]
        value_to_replace = polygon_i.face[row_idx, col_idx]
        polygon_i.face[row_idx, col_idx] = (polygon_data_list[polygonID].nodeID == value_to_replace).nonzero().item()
    polygon_i.faces = polygon_i.face.long()

    # 各行の三角形からエッジを抽出してedge_indexを構築
    edges = torch.cat([ polygon_i.faces[:, [0, 1]],
                        polygon_i.faces[:, [1, 2]],
                        polygon_i.faces[:, [2, 0]]], dim=0)

    # エッジのインデックスをソートして重複を削除
    edge_index = torch.sort(edges, dim=1).values
    edge_index = torch.tensor(sorted(edge_index.numpy().tolist())).unique(dim=0)
    polygon_i.edge_index = torch.transpose(edge_index, 0, 1)
    return polygon_i

# %% [markdown]
# # メッシュをプロットする関数

# %%
def plot_mesh(mesh, title):

    vertices = mesh.coordinates
    faces = mesh.faces
    fig = plt.figure()
    ax = fig.add_subplot(111, aspect="equal")

    # 描画するメッシュの頂点をプロット
    # ax.plot(vertices[:,0], vertices[:,1], 'bo')  # 頂点を青色の点でプロット
    # ax.plot(vertices[:,0], vertices[:,1], 'k-')  # 辺を黒色の線でプロット

    # 各三角形をプロット
    for face in faces:
        v0, v1, v2 = vertices[face]
        v0_np = v0.detach().cpu()#.numpy()
        v1_np = v1.detach().cpu()#.numpy()
        v2_np = v2.detach().cpu()#.numpy()
        ax.plot([v0_np[0], v1_np[0], v2_np[0], v0_np[0]], [v0_np[1], v1_np[1], v2_np[1], v0_np[1]], 'b-')  # 三角形を赤色の線でプロット

    ax.set_title(title)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.axhline(0, color="black", linewidth=0.001)
    ax.axvline(0, color="black", linewidth=0.001)

    # plt.xlim(-300, 150)
    # plt.ylim(-200, 1400)
    # plt.savefig(f"/mnt/{title}.png", format="png")
    plt.show()
    plt.close()

# %%
def save_mesh(mesh, title):

    vertices = mesh.coordinates
    faces = mesh.faces
    fig = plt.figure()
    ax = fig.add_subplot(111, aspect="equal")

    # 描画するメッシュの頂点をプロット
    # ax.plot(vertices[:,0], vertices[:,1], 'bo')  # 頂点を青色の点でプロット
    # ax.plot(vertices[:,0], vertices[:,1], 'k-')  # 辺を黒色の線でプロット

    # 各三角形をプロット
    for face in faces:
        v0, v1, v2 = vertices[face]
        v0_np = v0.detach().numpy()
        v1_np = v1.detach().numpy()
        v2_np = v2.detach().numpy()
        ax.plot([v0_np[0], v1_np[0], v2_np[0], v0_np[0]], [v0_np[1], v1_np[1], v2_np[1], v0_np[1]], 'b-')  # 三角形を赤色の線でプロット

    ax.set_title(title)
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.axhline(0, color="black", linewidth=0.001)
    ax.axvline(0, color="black", linewidth=0.001)

    # plt.xlim(-300, 150)
    # plt.ylim(-200, 1400)
    plt.savefig(f"{save_fig_path}{title}.png", format="png")
    # plt.show()
    plt.close()

# %% [markdown]
# # meshデータからvtkファイルを出力する関数

# %%
def vtk_output(mesh, title):
    vertices = mesh.coordinates
    faces = mesh.faces
    num_vertices = len(vertices)
    num_faces = len(faces)


    # vertices を３次元に戻す
    z_column = torch.zeros(vertices.shape[0], 1)
    vertices = torch.cat((vertices, z_column), dim=1)

    with open(f"/mnt/optimized_data/{title}.vtk", "w") as f:
        f.write("# vtk DataFile Version 2.0\n")
        f.write("FOR TEST\n")
        f.write("ASCII\n")
        f.write("DATASET POLYDATA\n")

        f.write("POINTS {} float\n".format(num_vertices))
        for vertex in vertices:
            f.write("{:.15f} {:.15f} {:.15f}\n".format(*vertex))

        f.write("\nPOLYGONS {} {}\n".format(num_faces, num_faces * 4))
        for face in faces:
            f.write("3 ")
            f.write(" ".join(str(idx.item()) for idx in face))
            f.write("\n")

# %% [markdown]
# # Normalization

# %%
def normalization(polygon):
    vertices = polygon.coordinates.to(device)
    normalized_vertices = vertices.to(device)
    centered_vertices = vertices.to(device)
    # print(vertices)

    max_x = torch.max(vertices[:,0]).to(device)
    min_x = torch.min(vertices[:,0]).to(device)
    max_y = torch.max(vertices[:,1]).to(device)
    min_y = torch.min(vertices[:,1]).to(device)

    polygon.d = torch.max(max_x - min_x, max_y - min_y).to(device)
    polygon.x_min = min_x.to(device)
    polygon.y_min = min_y.to(device)

    normalized_vertices = (vertices - torch.tensor([polygon.x_min, polygon.y_min]).to(device)) / polygon.d
    normalized_vertices.to(device)

    
    polygon.Cx = torch.tensor(normalized_vertices[0,0].item()).to(device)
    polygon.Cy = torch.tensor(normalized_vertices[0,1].item()).to(device)

    centered_vertices = normalized_vertices - torch.tensor([polygon.Cx, polygon.Cy]).to(device)
    polygon.coordinates = centered_vertices
    
    # print("Normalized polygon:", vertices)

    return polygon

# %% [markdown]
# # denormalization

# %%
def denormalization(polygon):
    vertices = polygon.coordinates.to(device)
    shifted_vertices = vertices.to(device)
    denormalized_vertices = vertices.to(device)
    
    shifted_vertices = vertices + torch.tensor([polygon.Cx, polygon.Cy]).to(device)
    
    
    denormalized_vertices = polygon.d * shifted_vertices + torch.tensor([polygon.x_min, polygon.y_min]).to(device)
    polygon.coordinates = denormalized_vertices
    return polygon

# %% [markdown]
# # Downscaling

# %%
def downscaling(polygon):
    vertices = polygon.coordinates
    polygon.coordinates = vertices * 0.9

    return polygon

# %% [markdown]
# # MetricLoss

# %%
# ログをファイルに保存するようにしている
import sys

import logging

logging.basicConfig(
    filename='metric_loss.log',
    level=logging.DEBUG, 
    format='%(message)s'
)

# logger = logging.getLogger(__name__)

class MetricLoss:
    def select_vertices(self, vertices, face):
        v0 = vertices[face[0]].to(device)
        v1 = vertices[face[1]].to(device)
        v2 = vertices[face[2]].to(device)
        if torch.isnan(v0).any() or torch.isnan(v1).any() or torch.isnan(v2).any():
            print("Error in vertices")
            
        return v0, v1, v2 

    def edge_length(self, v0, v1, v2):
        l1 = torch.sqrt((v0[0] - v1[0])**2 + (v0[1] - v1[1])**2)
        l2 = torch.sqrt((v1[0] - v2[0])**2 + (v1[1] - v2[1])**2)
        l3 = torch.sqrt((v2[0] - v0[0])**2 + (v2[1] - v0[1])**2)
        if torch.isnan(l1) or torch.isnan(l2) or torch.isnan(l3):
            print("Error in edge_length")
        return l1, l2, l3

    def face_area(self, polygon, l1, l2, l3):   # エラーのときはポリゴンを表示する
        
        s = 0.5*(l1 + l2 + l3)
        #print(round(l1.item(),5), round(l2.item(),5), round(l3.item(),5), round(s.item(),5), round((s*(s-l1)*(s-l2)*(s-l3)).item(),5))
        temp = s*(s-l1)*(s-l2)*(s-l3)
        #temp.register_hook(print_grad)
        # logger.info("    s, in_sqrt: {}, {}".format(s.item(), temp.item()))
        
        # try:
            
        face_area = torch.sqrt(temp)
            
        # except Exception as e:
            
            # SimplePolygonGenerator.polygon_visualizer(polygon)
            
            # print("An error occurred")
            # print("Value of temp:", temp)
            # print(l1.item(), l2.item(), l3.item())
            
        #     raise
        if torch.isnan(face_area):
            print("Error in face_area")
            print("temp:", temp)
        #face_area = torch.sqrt(temp)
        #face_area.register_hook(print_grad)
        return face_area

    def compute_loss(self, polygon, vertices, face, dx):
        v0, v1, v2 = self.select_vertices(vertices, face)
                  # わからんけどどれか原点にあるやつが自由点だからそれを移動させよう
        # if face[0]==0:
        #     v0 = v0 + dx
        # elif face[1]==0:
        #     v1 = v1 + dx
        # elif face[2]==0:
        #     v2 = v2 + dx
        #print(v0, v1, v2)
        # logger.info("    v0: ({}, {})".format(v0[0].item(), v0[1].item()))
        # logger.info("    v1: ({}, {})".format(v1[0].item(), v1[1].item()))
        # logger.info("    v2: ({}, {})".format(v2[0].item(), v2[1].item()))
        l1, l2, l3 = self.edge_length(v0, v1, v2)
        # logger.info("    l1, l2, l3:  {}, {}, {}".format(l1.item(), l2.item(), l3.item()))
        s = self.face_area(polygon, l1, l2, l3)
        #print(s.item(), l1.item(), l2.item(), l3.item())

        #q = (l1**2 + l2**2 + l3**2)/(4.0*torch.sqrt(torch.tensor(3.))*s+1.0)
        
        #loss = 1 - 1/q
        #print(q.item(), loss.item())
        
        #q = q.clone().detach().requires_grad_(True)
        loss = 1-(4.0*torch.sqrt(torch.tensor(3.))*s)/(l1**2 + l2**2 + l3**2)
        # logger.info("    area, loss: {}, {}".format(s.item(), loss.item()))
        # logger.info("")
        #print(loss.item())
        #print("")
        
        #loss.register_hook(print_grad)
        
        return loss

    def __call__(self, polygon, dx=None):
        vertices = polygon.coordinates
        faces = polygon.faces
        loss = torch.tensor(0.0)
        for face in faces:
            loss = loss + self.compute_loss(polygon, vertices, face, dx)
        
        metric_loss = loss/(len(polygon.coordinates[:,0])-1) #.clone().detach().requires_grad_(True))
        if torch.isnan(metric_loss):
            print("coordinates:", vertices)
            print("faces:", faces)  
            plot_mesh(polygon, "Current Polygon")
            print("Error: Loss value is NaN. Exiting program.")
            sys.exit(1)
        return metric_loss
    
    
def print_grad(grad):
    print(grad)

# %% [markdown]
# # meshデータからq_hatを求める関数

# %%
def calculate_q_hat(mesh):
    vertices = mesh.coordinates
    faces = mesh.faces
    r_list = []
    alpha_list = []
    beta_list = []

    for face in faces:
        # a(最小角)と b(最大角)を求める

        angles = []
        v0, v1, v2 = m_loss.select_vertices(vertices, face)
        l1, l2, l3 = m_loss.edge_length(v0, v1, v2)

        # 余弦定理から各角度の余弦値を計算
        cos_alpha = (l2**2 + l3**2 - l1**2) / (2*l2*l3)
        cos_beta = (l1**2 + l3**2 - l2**2) / (2*l1*l3)
        cos_gamma = (l1**2 + l2**2 - l3**2) / (2*l1*l2)
        # 余弦値から角度を計算して個度法に変換
        alpha = torch.acos(cos_alpha) * 180 / np.pi
        beta = torch.acos(cos_beta) * 180 / np.pi
        gamma = torch.acos(cos_gamma) * 180 / np.pi

        angles.append(alpha)
        angles.append(beta)
        angles.append(gamma)

        min_angle = min(angles)
        max_angle = max(angles)

        alpha_list.append(min_angle)
        beta_list.append(max_angle)

    # 1/q = r を求める
    for i in range(len(test_polygonID_list)):
        polygonID = i 
        polygon = data_getter(polygonID, 0, test_mesh_data_lists, test_polygon_data_list)

        r = 1 - m_loss(polygon) 
        r_list.append(r)

    a_mean = sum(alpha_list) / len(alpha_list)
    a_min = min(alpha_list)
    b_mean = sum(beta_list) / len(beta_list)
    b_max = max(beta_list)
    r_mean = sum(r_list) / len(r_list)
    r_min = min(r_list)

    q_hat = (((a_mean + a_min + 120 - b_max - b_mean)/60) + r_mean + r_min) / 6

    return q_hat

    

def calculate_qhat(mesh):
    vertices = mesh.coordinates
    faces = mesh.faces
    r_list = []
    alpha_list = []
    beta_list = []

    for face in faces:
        # a(最小角)と b(最大角)を求める

        angles = []
        v0, v1, v2 = m_loss.select_vertices(vertices, face)
        l1, l2, l3 = m_loss.edge_length(v0, v1, v2)

        # 余弦定理から各角度の余弦値を計算
        cos_alpha = (l2**2 + l3**2 - l1**2) / (2*l2*l3)
        cos_beta = (l1**2 + l3**2 - l2**2) / (2*l1*l3)
        cos_gamma = (l1**2 + l2**2 - l3**2) / (2*l1*l2)
        # 余弦値から角度を計算して個度法に変換
        alpha = torch.acos(cos_alpha) * 180 / np.pi
        beta = torch.acos(cos_beta) * 180 / np.pi
        gamma = torch.acos(cos_gamma) * 180 / np.pi

        angles.append(alpha)
        angles.append(beta)
        angles.append(gamma)

        min_angle = min(angles)
        max_angle = max(angles)

        alpha_list.append(min_angle)
        beta_list.append(max_angle)

        # 1/q = r を求める
        v0, v1, v2 = m_loss.select_vertices(vertices, face)
        l1, l2, l3 = m_loss.edge_length(v0, v1, v2)
        s = 0.5*(l1 + l2 + l3)
        temp = s*(s-l1)*(s-l2)*(s-l3)
        loss = 1-(4.0*torch.sqrt(torch.tensor(3.))*s)/(l1**2 + l2**2 + l3**2)
        r_list.append(1./loss)



    a_mean = sum(alpha_list) / len(alpha_list)
    a_min = min(alpha_list)
    b_mean = sum(beta_list) / len(beta_list)
    b_max = max(beta_list)
    r_mean = sum(r_list) / len(r_list)
    r_min = min(r_list)

    q_hat = (((a_mean + a_min + 120 - b_max - b_mean)/60) + r_mean + r_min) / 6

    return q_hat

# %% [markdown]
# スターポリゴンの中から外側に自由点が移動したときに自由点の移動量を半分にしてもう一度外に行っていないか検証する
# 自由点が外に行かないことを確認したあとのスターポリゴンを返す

# %%
def check(polygon):
    # print("polygonID:", polygonID)
    vertices = polygon.coordinates
    
    edge_index = polygon.edge_index
    
    return_value = True
    while return_value == True:   

        for i in range(1, len(vertices[:,0])):
            point1 = torch.tensor([0.0, 0.0])
            point2 = vertices[0]
            point3 = vertices[i]
            
            pos_i = torch.where(edge_index[0] == i)
            pos_i = pos_i[0]
            # print("edge_index[0]", edge_index[0])
            
            for j in range(len(pos_i)):
                if edge_index[1, pos_i[j]] == 0:
                    continue
                else:
                    val_pos_i = edge_index[1, pos_i[j]]
                    break

            point4 = vertices[val_pos_i]


            a1 = 0
            b1 = 0
            a2 = 0
            b2 = 0
            check1 = 0
            check2 = 0
            check3 = 0
            check4 = 0
            x1 = point1[0]
            y1 = point1[1]
            x2 = point2[0]
            y2 = point2[1]
            x3 = point3[0]
            y3 = point3[1]
            x4 = point4[0]
            y4 = point4[1]
            a1 = (y1 - y2)/(x1-x2)
            b1 = y1 - (a1*x1)
            a2 = (y3 - y4)/(x3-x4)
            b2 = y3 - (a2*x3)
            check1 = (a1*x3) - y3 + b1 
            check2 = (a1*x4) - y4 + b1    # point1,2を通る直線に対してpoint3,4を結ぶ線分が交差しているか
            check3 = (a2*x1) - y1 + b2
            check4 = (a2*x2) - y2 + b2    # point3,4を通る直線に対してpoint1,2を結ぶ線分が交差しているか
            # print("1:",check1,"2:",check2,"3:",check3,"4:",check4)
            del a1, a2, b1, b2, x1, x2, x3, x4, y1, y2, y3, y4 

            if (check1*check2) <= 0.1 and (check3*check4) <= 0.1 :
                return_value = True
                # print("Out_of_StarPolygon")
                vertices[0] = 0.5*vertices[0]
                polygon.coordinates[0] = vertices[0]
                break
            else:
                return_value = False
                continue       
            
        
    # plot_mesh(polygon, "polygon_checked")
               
    return polygon

# %% [markdown]
# # Model 隠れ層のノード数は何にするか未定

# %%
class GMSNet(torch.nn.Module):
    
    def __init__(self, input_dim, feature_dim, hidden_channels):   # モデルの初期化
        
        super(GMSNet, self).__init__()
        
        self.fc1 = Linear(input_dim, feature_dim)
        self.gcn = GCNConv(feature_dim, feature_dim)
        self.graph_norm = GraphNorm(feature_dim)
        self.instance_norm = nn.InstanceNorm1d(feature_dim)
        self.fc2 = nn.Linear(feature_dim, feature_dim)
        self.fc3 = nn.Linear(feature_dim, input_dim)


        # Weight initialization
        self.apply(self._init_weights)                                  # 重みの初期化

    def _init_weights(self, m):     # 線形層と畳み込み層の重みをKaiming正規化で初期化し、バイアスをゼロで初期化する
        if isinstance(m, (nn.Linear, nn.Conv1d)):
            nn.init.kaiming_normal_(m.weight, nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)

    def forward(self, x, edge_index):       
        
        x = self.fc1(x)
        x = self.graph_norm(x)
        x = F.relu(x)
        x = self.gcn(x, edge_index) + x
        x = self.fc2(x)
        # x = self.instance_norm(x)
        x = self.fc3(x)
        x = 0.1 * x 
        x = x[0]

        
        
        return x

# %% [markdown]
# # Main

# %%
# フォルダ内のすべてのvtkファイルにアクセスする
train_vtk_files = glob.glob(f"{train_data_path}*.vtk")
train_vtk_filenames = [file.split('/')[-1].split('.')[0] for file in train_vtk_files]

num_train_mesh = len(train_vtk_files)
print("num_train_mesh:", num_train_mesh)
train_mesh_data_list, train_polygonID_list, train_polygon_dict = create_mesh_polygon_dataset(train_vtk_files)



    
# ポリゴンデータを格納するリストを作成
train_polygon_data_list = []

for i in range(len(train_polygonID_list)):
    polygonID = f"polygon_{i}"
    meshID = train_polygon_dict[f"polygon_{i}"][0]
    nodeID = train_polygon_dict[f"polygon_{i}"][1]
    polygon_data = Polygon_data(polygonID, meshID, nodeID)
    train_polygon_data_list.append(polygon_data)
# Out:
# num_train_mesh: 4
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 358
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 359
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 360
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 361
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 362
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 363
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 364
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 365
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 366
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 367
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 368
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 369
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 370
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 371
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 372
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 373
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 374
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 375
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 376
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 377
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 378
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 379
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 380
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 381
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 382
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 383
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 384
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 385
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 386
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 387
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 388
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 389
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 390
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 391
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 392
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 393
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 394
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 395
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 396
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 397
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 398
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 399
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 400
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 401
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 402
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 403
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 404
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 405
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 406
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 407
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 408
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 409
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 410
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 411
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 412
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 413
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 414
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 415
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 416
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 417
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 418
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 419
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 420
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 421
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 422
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 423
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 424
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 425
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 426
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 427
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 428
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 429
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 430
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 431
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 432
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 433
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 434
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 435
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 436
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 437
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 438
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 439
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 440
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 441
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 442
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 443
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 444
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 445
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 446
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 447
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 448
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 449
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 450
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 451
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 452
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 453
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 454
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 455
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 456
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 457
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 458
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 459
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 460
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 461
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 462
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 463
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 464
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 465
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 466
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 467
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 468
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 469
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 470
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 471
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 472
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 473
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 474
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 475
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 476
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 477
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 478
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 479
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 480
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 481
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 482
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 483
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 484
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 485
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 486
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 487
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 488
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 489
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 490
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 491
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 492
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 493
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 494
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 495
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 496
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 497
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 498
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 499
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 500
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 501
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 502
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 503
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 504
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 505
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 506
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 507
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 508
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 509
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 510
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 511
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 512
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 513
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 514
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 515
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 516
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 517
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 518
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 519
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 520
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 521
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 522
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 523
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 524
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 525
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 526
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 527
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 528
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 529
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 530
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 531
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 532
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 533
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 534
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 535
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 536
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 537
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 538
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 539
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 540
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 541
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 542
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 543
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 544
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 545
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 546
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 547
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 548
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 549
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 550
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 551
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 552
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 553
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 554
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 555
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 556
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 557
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 558
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 559
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 560
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 561
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 562
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 563
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 564
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 565
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 566
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 567
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 568
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 569
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 570
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 571
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 572
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 573
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 574
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 575
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 576
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 577
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 578
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 579
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 580
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 581
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 582
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 583
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 584
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 585
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 586
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 587
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 588
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 589
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 590
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 591
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 592
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 593
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 594
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 595
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 596
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 597
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 598
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 599
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 600
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 601
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 602
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 603
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 604
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 605
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 606
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 607
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 608
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 609
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 610
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 611
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 612
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 613
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 614
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 615
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 616
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 617
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 618
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 619
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 620
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 621
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 622
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 623
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 624
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 625
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 626
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 627
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 628
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 629
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 630
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 631
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 632
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 633
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 634
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 635
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 636
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 637
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 638
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 639
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 640
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 641
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 642
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 643
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 644
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 645
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 646
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 647
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 648
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 649
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 650
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 651
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 652
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 653
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 654
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 655
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 656
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 657
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 658
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 659
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 660
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 661
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 662
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 663
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 664
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 665
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 666
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 667
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 668
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 669
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 670
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 671
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 672
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 673
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 674
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 675
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 676
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 677
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 678
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 679
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 680
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 681
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 682
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 683
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 684
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 685
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 686
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 687
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 688
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 689
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 690
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 691
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 692
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 693
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 694
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 695
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 696
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 697
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 698
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 699
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 700
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 701
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 702
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 703
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 704
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 705
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 706
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 707
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 708
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 709
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 710
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 711
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 712
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 713
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 714
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 715
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 716
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 717
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 718
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 719
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 720
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 721
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
#   Debug: Off
#   Modified Time: 722
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e370ff0)
#   Debug: Off
#   Modified Time: 723
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e387170)
# ...
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5469
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5470
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5471
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5472
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5473
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5474
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5475
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5476
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5477
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5478
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5479
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5480
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5481
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5482
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5483
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5484
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5485
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5486
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5487
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5488
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5489
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5490
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5491
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5492
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5493
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5494
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5495
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5496
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5497
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5498
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5499
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5500
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5501
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5502
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5503
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5504
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5505
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5506
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5507
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5508
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5509
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5510
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5511
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5512
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5513
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5514
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5515
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5516
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5517
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5518
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5519
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5520
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5521
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5522
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5523
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5524
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5525
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5526
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5527
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5528
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5529
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5530
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5531
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5532
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5533
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5534
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5535
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5536
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5537
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5538
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5539
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5540
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5541
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5542
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5543
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5544
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5545
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5546
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5547
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5548
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5549
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5550
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5551
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5552
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5553
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5554
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5555
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5556
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5557
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5558
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5559
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5560
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5561
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5562
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5563
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5564
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5565
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5566
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5567
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5568
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5569
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5570
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5571
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5572
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5573
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5574
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5575
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5576
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5577
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5578
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5579
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5580
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5581
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5582
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5583
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5584
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5585
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5586
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5587
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e4615e0)
#   Debug: Off
#   Modified Time: 5588
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0
#
#
# vtkIdList (0x55f23e434ce0)
#   Debug: Off
#   Modified Time: 5589
#   Reference Count: 1
#   Registered Events: (none)
#   Number of Ids: 0

# %%
type(train_polygon_data_list[0])
# Out:
# __main__.Polygon_data

# %%
torch.manual_seed(42)
train_data_loader = DataLoader(train_polygonID_list, batch_size=64*num_train_mesh, shuffle=True)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
model = GMSNet(input_dim=2, feature_dim=64, hidden_channels=64)
model.to(device)
print(model)
optimizer = torch.optim.Adam(model.parameters(),lr=0.01)
criterion = MetricLoss()
early_stopping = EarlyStopping(patience=5, min_delta=1e-6)
# Out:
# cuda
# GMSNet(
#   (fc1): Linear(in_features=2, out_features=64, bias=True)
#   (gcn): GCNConv(64, 64)
#   (graph_norm): GraphNorm(64)
#   (instance_norm): InstanceNorm1d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
# writer = SummaryWriter("logs")
# 学習率を調整するスケジューラの設定
scheduler = ReduceLROnPlateau(optimizer, mode="min", patience=2, factor=0.95, verbose=True)

loss_list = []

def train(device):
    model.train()

    # for name, param in model.GNorm.named_parameters():
    #     print(f'{name}:{param.data}')

    model.to(device)
    
    temp = 0
    ddd = 0
    
    for step, data in enumerate(train_data_loader):
        
        optimizer.zero_grad()
        metric_loss = torch.tensor(0.0, requires_grad=True)
        metric_loss.to(device)
        dx_list = []
        
        for i in range(len(data)):

            polygonID = int(data[i].split("_")[-1])
            polygon = data_getter(polygonID, 0, train_mesh_data_list, train_polygon_data_list)
            polygon.to(device)
            polygon = normalization(polygon)
            x = polygon.coordinates.to(device)
            edge_index = polygon.edge_index.to(device)
            out = model(x, edge_index)
            polygon.coordinates[0] = polygon.coordinates[0] + out
            # polygon = check(polygon)
            
            
            
            # logger.info("epoch: {:04}, polygonID: {:04}".format(epoch, polygonID))
            # logger.info("before")
            with torch.no_grad():
                l = criterion(polygon)

            
            # logger.info("")
            # print(l)
            metric_loss = metric_loss + l
            polygon = denormalization(polygon)
            if torch.abs(polygon.coordinates[0][0] - 50) < 10 and torch.abs(polygon.coordinates[0][1]) < 60:
                polygon = normalization(polygon)
                polygon = downscaling(polygon)
                polygon = denormalization(polygon)
                
            polygon_meshID = int(train_polygon_data_list[polygonID].meshID.split("_")[-1])
            mesh = train_mesh_data_list[polygon_meshID]
            mesh.coordinates[train_polygon_data_list[polygonID].nodeID] = polygon.coordinates.cpu()
            
            
        loss = metric_loss/len(data)
        

            
        ddd = ddd + len(data)
        temp = temp + loss
        # print("    Loss:", loss.item(), "   PolygonID:", polygonID)
        
        loss.backward()
        optimizer.step()

    loss_ave = temp/ddd
    writer.add_scalar("loss", loss_ave, epoch)       
    print(loss_ave, epoch)
    loss_list.append(temp/ddd)

# %%
for i in range(num_train_mesh):
    plot_mesh(train_mesh_data_list[i], f"original_{train_vtk_filenames[i]}")

# %% [markdown]
# # 最終的な最適化したメッシュを生成してvtkファイルで出力する

# %%
# TensorBoard用のログディレクトリを指定
writer = SummaryWriter(log_dir="/mnt/log/test" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "train")

# %%
epoch = 0
import torch
torch.autograd.set_detect_anomaly(True)

for j in range(num_train_mesh):                 # 元のメッシュを保存する
        save_mesh(train_mesh_data_list[j], f"trained_{train_vtk_filenames[j]}_{epoch}")
# torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)            
for epoch in tqdm(range(num_train_epoch)):
    #print("epoch:", epoch)
    train(device)
    # print(epoch)

    # for i in range(num_train_mesh):
    #     plot_mesh(train_mesh_data_list[i], f"{i}")
    for j in range(num_train_mesh):             # 最適化したメッシュを保存する
        save_mesh(train_mesh_data_list[j], f"trained_{train_vtk_filenames[j]}_{epoch+1}")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# tensor(0.0009, device='cuda:0', grad_fn=<DivBackward0>) 0
#   2%|▏         | 1/50 [00:37<30:55, 37.87s/it]
# tensor(0.0007, device='cuda:0', grad_fn=<DivBackward0>) 1
#   4%|▍         | 2/50 [01:15<30:20, 37.93s/it]
# tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>) 2
#   6%|▌         | 3/50 [01:53<29:39, 37.85s/it]
# tensor(0.0006, device='cuda:0', grad_fn=<DivBackward0>) 3
#   8%|▊         | 4/50 [02:31<29:05, 37.95s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 4
#  10%|█         | 5/50 [03:10<28:35, 38.11s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 5
#  12%|█▏        | 6/50 [03:49<28:14, 38.51s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 6
#  14%|█▍        | 7/50 [04:26<27:16, 38.05s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 7
#  16%|█▌        | 8/50 [05:05<26:50, 38.34s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 8
#  18%|█▊        | 9/50 [05:42<25:57, 37.98s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 9
#  20%|██        | 10/50 [06:22<25:48, 38.70s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 10
#  22%|██▏       | 11/50 [07:00<24:53, 38.29s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 11
#  24%|██▍       | 12/50 [07:38<24:07, 38.11s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 12
#  26%|██▌       | 13/50 [08:19<24:05, 39.08s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 13
#  28%|██▊       | 14/50 [08:59<23:43, 39.53s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 14
#  30%|███       | 15/50 [09:38<22:54, 39.26s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 15
#  32%|███▏      | 16/50 [10:20<22:44, 40.14s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 16
#  34%|███▍      | 17/50 [10:58<21:43, 39.51s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 17
#  36%|███▌      | 18/50 [11:36<20:46, 38.96s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 18
#  38%|███▊      | 19/50 [12:13<19:54, 38.53s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 19
#  40%|████      | 20/50 [12:57<19:57, 39.92s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 20
#  42%|████▏     | 21/50 [13:35<18:59, 39.31s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 21
#  44%|████▍     | 22/50 [14:13<18:13, 39.07s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 22
#  46%|████▌     | 23/50 [14:52<17:30, 38.90s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 23
#  48%|████▊     | 24/50 [15:30<16:46, 38.73s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 24
#  50%|█████     | 25/50 [16:08<16:04, 38.59s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 25
#  52%|█████▏    | 26/50 [16:53<16:11, 40.49s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 26
#  54%|█████▍    | 27/50 [17:31<15:16, 39.85s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 27
#  56%|█████▌    | 28/50 [18:10<14:25, 39.35s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 28
#  58%|█████▊    | 29/50 [18:48<13:39, 39.02s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 29
#  60%|██████    | 30/50 [19:26<12:57, 38.86s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 30
#  62%|██████▏   | 31/50 [20:05<12:14, 38.67s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 31
#  64%|██████▍   | 32/50 [20:51<12:18, 41.04s/it]
# tensor(0.0004, device='cuda:0', grad_fn=<DivBackward0>) 32
#  66%|██████▌   | 33/50 [21:29<11:23, 40.21s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 33
#  68%|██████▊   | 34/50 [22:08<10:33, 39.62s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 34
#  70%|███████   | 35/50 [22:46<09:50, 39.39s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 35
#  72%|███████▏  | 36/50 [23:27<09:17, 39.82s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 36
#  74%|███████▍  | 37/50 [24:08<08:41, 40.10s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 37
#  76%|███████▌  | 38/50 [24:49<08:02, 40.24s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 38
#  78%|███████▊  | 39/50 [25:29<07:23, 40.33s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 39
#  80%|████████  | 40/50 [26:20<07:14, 43.40s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 40
#  82%|████████▏ | 41/50 [26:59<06:19, 42.12s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 41
#  84%|████████▍ | 42/50 [27:39<05:31, 41.47s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 42
#  86%|████████▌ | 43/50 [28:18<04:45, 40.74s/it]
# tensor(0.0005, device='cuda:0', grad_fn=<DivBackward0>) 43
#  88%|████████▊ | 44/50 [28:57<04:00, 40.16s/it]
# Error in face_area
# temp: tensor(-1.8196e-09, device='cuda:0')
# coordinates: tensor([[ 0.0345,  0.0057],
#         [-0.2349, -0.0110],
#         [-0.1894,  0.0441],
#         [ 0.0837,  0.0253],
#         [-0.1297, -0.0783],
#         [ 0.0959, -0.1083],
#         [ 0.7651,  0.2970]], device='cuda:0', grad_fn=<CopySlices>)
# faces: tensor([[2, 1, 0],
#         [2, 0, 3],
#         [0, 1, 4],
#         [4, 5, 0],
#         [0, 5, 6],
#         [0, 6, 3]], device='cuda:0')
#  88%|████████▊ | 44/50 [29:24<04:00, 40.09s/it]
# Error: Loss value is NaN. Exiting program.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
writer.close()

# %%
print(model)

# %% [markdown]
# メモリの開放をする

# %%
torch.save(model.state_dict(), 'model_weights.pth')

gc.collect()

if torch.cuda.is_available():
    torch.cuda.empty_cache()
